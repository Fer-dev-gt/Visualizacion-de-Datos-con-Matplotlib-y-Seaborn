# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5, 11)
y = x ** 2
print(x)
print(y)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# [ 0.    0.25  1.    2.25  4.    6.25  9.   12.25 16.   20.25 25.  ]

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.5, 0.9])
axes.plot(x, y, 'r')
fig.show()
# Out:
# /var/folders/tw/h0zr9bg96rj0s75cfrtqb2nr0000gn/T/ipykernel_51041/1232662972.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 2, 3])
axes.plot(x, y, 'r')
fig.show()
# Out:
# /var/folders/tw/h0zr9bg96rj0s75cfrtqb2nr0000gn/T/ipykernel_51041/2510655515.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.9])
axes2 = fig.add_axes([0.2, 0.55, 0.4, 0.3])

axes.plot(x, y, 'r')
axes2.plot(y, x, 'b')
axes2.set_facecolor('yellow')

fig.show()
# Out:
# /var/folders/tw/h0zr9bg96rj0s75cfrtqb2nr0000gn/T/ipykernel_51041/3188497033.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
