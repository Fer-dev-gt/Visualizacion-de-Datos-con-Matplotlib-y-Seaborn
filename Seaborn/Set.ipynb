# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x=['A', 'B', 'C'], y=[1, 3, 2])
plt.show()

# %%
sns.set(style='darkgrid', palette='deep', font='Verdana', font_scale=2)
sns.barplot(x=['A', 'B', 'C'], y=[1, 3, 2])
plt.show()
